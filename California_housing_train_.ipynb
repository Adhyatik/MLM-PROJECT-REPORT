# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhyatik/MLM-PROJECT-REPORT/blob/main/California_housing_train_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.0 Call Libraries
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
data = pd.read_csv("/content/sample_data/california_housing_train.csv")
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
data.shape
print("\n=====\n")
data.dtypes
# Out:
# (17000, 9)
# =====
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
y = data.pop("median_house_value")
x= data

# %%
model= tf.keras.Sequential()

# %%
model.add(layers.Input(shape = (8,) ))

# %%
model.add(layers.Dense(64, activation = 'relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(32, activation='selu'))
model.add(layers.Dropout(0.4))

# %%
model.add(layers.Dense(1, activation='linear'))

# %%
model.compile( loss = "mae")

# %%
model.fit(x,y, epochs = 200)
# Out:
# Epoch 1/200
# 532/532 [==============================] - 2s 2ms/step - loss: 144600.5000
# Epoch 2/200
# 532/532 [==============================] - 1s 2ms/step - loss: 119984.2188
# Epoch 3/200
# 532/532 [==============================] - 1s 2ms/step - loss: 114031.3203
# Epoch 4/200
# 532/532 [==============================] - 1s 2ms/step - loss: 107759.0469
# Epoch 5/200
# 532/532 [==============================] - 1s 2ms/step - loss: 97841.1406
# Epoch 6/200
# 532/532 [==============================] - 1s 2ms/step - loss: 91990.0859
# Epoch 7/200
# 532/532 [==============================] - 1s 3ms/step - loss: 90131.7422
# Epoch 8/200
# 532/532 [==============================] - 2s 3ms/step - loss: 89195.2031
# Epoch 9/200
# 532/532 [==============================] - 1s 3ms/step - loss: 88834.6797
# Epoch 10/200
# 532/532 [==============================] - 1s 2ms/step - loss: 87856.5547
# Epoch 11/200
# 532/532 [==============================] - 1s 2ms/step - loss: 87901.6719
# ...
